# %% [markdown]
# ## Pandas
#
# ### Creating dataframes
#
# One common way would be to read a csv file. Here, we create the file first.

# %%
import pandas as pd

# %%
s = '''
A,B,C
√2,1,1.4142
phi,4,1.6180
e,9,2.7183
pi,16,3.1415
'''

fn = 'tmp'
with open(fn,'w') as fh:  fh.write(s)
df = pd.read_csv(fn)
df
# Out:
#      A   B       C
# 0   √2   1  1.4142
# 1  phi   4  1.6180
# 2    e   9  2.7183
# 3   pi  16  3.1415

# %% [markdown]
# One can also read from a dictionary.

# %%
D = {'fips':['16','41','53'],'abbrev':['ID','OR','WA']}
df2 = pd.DataFrame(D)
df2
# Out:
#   fips abbrev
# 0   16     ID
# 1   41     OR
# 2   53     WA

# %% [markdown]
# In the first example, we could have used the `io` module to treat the string as a file-like object:

# %%
import io
df3 = pd.read_csv(io.StringIO(s), sep=',')
df3
# Out:
#      A   B       C
# 0   √2   1  1.4142
# 1  phi   4  1.6180
# 2    e   9  2.7183
# 3   pi  16  3.1415

# %% [markdown]
# Assignment does **not** make a copy.

# %%
df4 = df
print(id(df),id(df4))
# Out:
# 4466056384 4466056384

# %%
df4 = df.drop('B',axis=1)

# %%
print(id(df),id(df4))
# Out:
# 4466056384 4466056528

# %% [markdown]
# Pandas protects us by returning the result from `drop` as a new dataframe.

# %%
df4
# Out:
#      A       C
# 0   √2  1.4142
# 1  phi  1.6180
# 2    e  2.7183
# 3   pi  3.1415

# %% [markdown]
# Of course, if you really want to change the original:

# %%
df4 = df
df.drop('B',axis=1,inplace=True)

# %%
print(id(df),id(df4))
# Out:
# 4466056384 4466056384

# %% [markdown]
# So then naturally

# %%
df4.columns
# Out:
# Index(['A', 'C'], dtype='object')

# %% [markdown]
# ### Working with columns

# %% [markdown]
# To select rows from a dataframe, first constructing a list of booleans. That list is formed by analyzing the values in one or more columns of the dataframe.

# %%
import io
df = pd.read_csv(io.StringIO(s), sep=',')
df
# Out:
#      A   B       C
# 0   √2   1  1.4142
# 1  phi   4  1.6180
# 2    e   9  2.7183
# 3   pi  16  3.1415

# %% [markdown]
# A plain old list will do.

# %%
L = [True,False,True,False]
df[L]
# Out:
#     A  B       C
# 0  √2  1  1.4142
# 2   e  9  2.7183

# %% [markdown]
# Normally the way to obtain a list of booleans is by matching the values in one or more columns against some filter. It's usually done in one step but we'll break it up by first making a selector.
#
# We use a special pandas method `isin`.

# %%
sel = df['A'].isin(list('abcde'))
sel
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: A, dtype: bool

# %%
print(type(sel))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[sel]
# Out:
#    A  B       C
# 2  e  9  2.7183

# %% [markdown]
# Another way that works is logical OR and AND:  `|`, `&`

# %%
df[(df['A'] == 'pi') | (df['B'] == 9)]
# Out:
#     A   B       C
# 2   e   9  2.7183
# 3  pi  16  3.1415

# %% [markdown]
# For complex searchs use `apply`, usually with a `lambda` expression, although it can also be a named function.

# %%
import numpy as np

def f(row):
    v = row['B']
    def f():
        return v in range(10)
    coin_flip = np.random.choice([0,1])
    if coin_flip:
        return f()
    return True

sel = df.apply(f,axis=1)

# %%
sel
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %% [markdown]
# Double brackets with column names returns those columns in the specified order.

# %%
df1 = df[['C','B']]
df1
# Out:
#         C   B
# 0  1.4142   1
# 1  1.6180   4
# 2  2.7183   9
# 3  3.1415  16

# %% [markdown]
# Adding a new column:

# %%
df1['F'] = [1,2,3,4]
df1
# Out:
#         C   B  F
# 0  1.4142   1  1
# 1  1.6180   4  2
# 2  2.7183   9  3
# 3  3.1415  16  4

# %%
a = df.to_numpy()
a
# Out:
# array([['√2', 1, 1.4142],
#        ['phi', 4, 1.618],
#        ['e', 9, 2.7183],
#        ['pi', 16, 3.1415]], dtype=object)

# %%
a[:,2]
# Out:
# array([1.4142, 1.618, 2.7183, 3.1415], dtype=object)

# %%
[float(n) for n in a[:,2]]
# Out:
# [1.4142, 1.618, 2.7183, 3.1415]

# %% [markdown]
# ### Working with rows

# %%
import pandas as pd
import numpy as np
np.random.seed(153)

a = np.random.randint(0,10,20)
a.shape = (5,4)
df = pd.DataFrame(a,columns=list('ABCD'))
df
# Out:
#    A  B  C  D
# 0  0  8  7  1
# 1  7  9  6  3
# 2  6  6  0  2
# 3  4  2  6  9
# 4  4  8  2  1

# %% [markdown]
# `loc` and `iloc`

# %%
df.loc[:,'C']
# Out:
# 0    7
# 1    6
# 2    0
# 3    6
# 4    2
# Name: C, dtype: int64

# %%
df.loc[1] # 1 is a label
# Out:
# A    7
# B    9
# C    6
# D    3
# Name: 1, dtype: int64

# %%
df.iloc[1] # 1 is an integer index
# Out:
# A    7
# B    9
# C    6
# D    3
# Name: 1, dtype: int64

# %%
df = df.drop(2)
df
# Out:
#    A  B  C  D
# 0  0  8  7  1
# 1  7  9  6  3
# 3  4  2  6  9
# 4  4  8  2  1

# %%
df.loc[3]
# Out:
# A    4
# B    2
# C    6
# D    9
# Name: 3, dtype: int64

# %%
df.iloc[3]
# Out:
# A    4
# B    8
# C    2
# D    1
# Name: 4, dtype: int64

# %%
df.iloc[[0,3]][['D','A']]
# Out:
#    D  A
# 0  1  0
# 4  1  4

# %% [markdown]
# Iterration

# %%
for i,r in df.iterrows():
    print(r['B'])
# Out:
# 8
# 9
# 2
# 8

# %% [markdown]
# Another way to access a single value:

# %%
df.at[1,'C']
# Out:
# np.int64(6)
